# %% [markdown]
# **Pandas Notebook 6**
#
# A demonstration of advanced `pandas` syntax to accompany class Lecture.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import plotly.express as px

# %% [markdown]
# #More on `Groupby`

# %% [markdown]
# Try to predict the results of the `groupby` operation shown. The answer is below the image.
# The top ?? will be "hi", the second ?? will be "tx", and the third ?? will be "sd".

# %%
# Form a data frame using dictionary
# Answer Here
ds = pd.DataFrame(dict(x=[3, 1, 4, 1, 5, 9, 2, 5, 6],
                      y=['ak', 'tx', 'fl', 'hi', 'mi', 'ak', 'ca', 'sd', 'nc']),
                      index=list('ABCABCACB') )
ds
# Out:
#    x   y
# A  3  ak
# B  1  tx
# C  4  fl
# A  1  hi
# B  5  mi
# C  9  ak
# A  2  ca
# C  5  sd
# B  6  nc

# %%
#Use groupby on index and get max of each group
ds.groupby(ds.index).max()
# Out:
#    x   y
# A  3  hi
# B  6  tx
# C  9  sd

# %% [markdown]
# ### `groupby.size` and `groupby.count()`

# %%
df = pd.DataFrame({'letter':['A', 'A', 'B', 'C', 'C', 'C'],
                   'num':[1, 2, 3, 4, np.NaN, 4],
                   'state':[np.NaN, 'tx', 'fl', 'hi', np.NaN, 'ak']})
df
# Out:
#   letter  num state
# 0      A  1.0   NaN
# 1      A  2.0    tx
# 2      B  3.0    fl
# 3      C  4.0    hi
# 4      C  NaN   NaN
# 5      C  4.0    ak

# %% [markdown]
# `groupby.size()` returns a `Series`, indexed by the `letter`s that we grouped by, with values denoting the number of rows in each group/sub-DataFrame. It does not care about missing (`NaN`) values.

# %%
# Use groupby with size()
df.groupby("letter").size()
# Out:
# letter
# A    2
# B    1
# C    3
# dtype: int64

# %% [markdown]
# `groupby.count()` returns a `DataFrame`, indexed by the `letter`s that we grouped by. Each column represents the number of non-missing values for that `letter`.

# %%
# Use groupby with count()
df.groupby("letter").count()
# Out:
#         num  state
# letter
# A         2      1
# B         1      1
# C         2      2

# %% [markdown]
# You might recall `value_counts()` function we talked about last week. What's the difference?

# %%
# Use value_count() on DataFrame described above
df.groupby("letter").value_counts()
# Out:
# letter  num  state
# A       2.0  tx       1
# B       3.0  fl       1
# C       4.0  ak       1
#              hi       1
# Name: count, dtype: int64

# %% [markdown]
# Turns out `value_counts()` does something similar to `groupby.size()`, except that it also sorts the resulting `Series` in descending order.

# %% [markdown]
# ## Filtering by Group

# %%
# Let's read the elections dataset
elections = pd.read_csv("/content/drive/MyDrive/elections.csv")
elections
# Out:
#      Year          Candidate                  Party  Popular vote Result  \
# 0    1824     Andrew Jackson  Democratic-Republican        151271   loss
# 1    1824  John Quincy Adams  Democratic-Republican        113142    win
# 2    1828     Andrew Jackson             Democratic        642806    win
# 3    1828  John Quincy Adams    National Republican        500897   loss
# 4    1832     Andrew Jackson             Democratic        702735    win
# ..    ...                ...                    ...           ...    ...
# 177  2016         Jill Stein                  Green       1457226   loss
# 178  2020       Joseph Biden             Democratic      81268924    win
# 179  2020       Donald Trump             Republican      74216154   loss
# 180  2020       Jo Jorgensen            Libertarian       1865724   loss
# 181  2020     Howard Hawkins                  Green        405035   loss
#
#              %
# 0    57.210122
# 1    42.789878
# 2    56.203927
# 3    43.796073
# 4    54.574789
# ..         ...
# 177   1.073699
# 178  51.311515
# 179  46.858542
# 180   1.177979
# 181   0.255731
#
# [182 rows x 6 columns]

# %% [markdown]
# Let's keep only the elections years where the maximum vote share `%` is less than 45%.

# %%
# use filter function
election_win_45 = elections.groupby("Year").filter(lambda max:max["%"].max() < 45)
election_win_45
# Out:
#      Year             Candidate                 Party  Popular vote Result  \
# 23   1860       Abraham Lincoln            Republican       1855993    win
# 24   1860             John Bell  Constitutional Union        590901   loss
# 25   1860  John C. Breckinridge   Southern Democratic        848019   loss
# 26   1860    Stephen A. Douglas   Northern Democratic       1380202   loss
# 66   1912        Eugene V. Debs             Socialist        901551   loss
# 67   1912      Eugene W. Chafin           Prohibition        208156   loss
# 68   1912    Theodore Roosevelt           Progressive       4122721   loss
# 69   1912          William Taft            Republican       3486242   loss
# 70   1912        Woodrow Wilson            Democratic       6296284    win
# 115  1968        George Wallace  American Independent       9901118   loss
# 116  1968       Hubert Humphrey            Democratic      31271839   loss
# 117  1968         Richard Nixon            Republican      31783783    win
# 139  1992          Andre Marrou           Libertarian        290087   loss
# 140  1992          Bill Clinton            Democratic      44909806    win
# 141  1992              Bo Gritz              Populist        106152   loss
# 142  1992     George H. W. Bush            Republican      39104550   loss
# 143  1992            Ross Perot           Independent      19743821   loss
#
#              % First Name
# 23   39.699408    Abraham
# 24   12.639283       John
# 25   18.138998       John
# 26   29.522311    Stephen
# 66    6.004354     Eugene
# 67    1.386325     Eugene
# 68   27.457433   Theodore
# 69   23.218466    William
# 70   41.933422    Woodrow
# 115  13.571218     George
# 116  42.863537     Hubert
# 117  43.565246    Richard
# 139   0.278516      Andre
# 140  43.118485       Bill
# 141   0.101918         Bo
# 142  37.544784     George
# 143  18.956298       Ross

# %% [markdown]
# ### `groupby` Puzzle
#
# Assume that we want to know the best election by each party.

# %% [markdown]
# #### Attempt #1

# %% [markdown]
# We have to be careful when using aggregation functions. For example, the code below might be misinterpreted to say that Woodrow Wilson successfully ran for election in 2020. Why is this happening?

# %%
# Use agg(max)
elections.groupby("Party").agg(max).head(10)
# Out:
# <ipython-input-40-4cefb6911cca>:2: FutureWarning: The provided callable <built-in function max> is currently using DataFrameGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   elections.groupby("Party").agg(max).head(10)
#                        Year           Candidate  Popular vote Result  \
# Party
# American               1976  Thomas J. Anderson        873053   loss
# American Independent   1976       Lester Maddox       9901118   loss
# Anti-Masonic           1832        William Wirt        100715   loss
# Anti-Monopoly          1884     Benjamin Butler        134294   loss
# Citizens               1980      Barry Commoner        233052   loss
# Communist              1932   William Z. Foster        103307   loss
# Constitution           2016    Michael Peroutka        203091   loss
# Constitutional Union   1860           John Bell        590901   loss
# Democratic             2020      Woodrow Wilson      81268924    win
# Democratic-Republican  1824   John Quincy Adams        151271    win
#
#                                % First Name
# Party
# American               21.554001     Thomas
# American Independent   13.571218     Lester
# Anti-Masonic            7.821583    William
# Anti-Monopoly           1.335838   Benjamin
# Citizens                0.270182      Barry
# Communist               0.261069    William
# Constitution            0.152398    Michael
# Constitutional Union   12.639283       John
# Democratic             61.344703    Woodrow
# Democratic-Republican  57.210122       John

# %% [markdown]
# #### Attempt #2

# %% [markdown]
# Next, we'll write code that properly returns _the best result by each party_. That is, each row should show the Year, Candidate, Popular Vote, Result, and % for the election in which that party saw its best results (rather than mixing them as in the example above). Here's what the first rows of the correct output should look like:

# %%
# Use sort and then groupby as describe in the lec
elections_sorted = elections.sort_values(by="%", ascending=False)
elections_sorted
# Out:
#      Year           Candidate         Party  Popular vote Result          %  \
# 114  1964      Lyndon Johnson    Democratic      43127041    win  61.344703
# 91   1936  Franklin Roosevelt    Democratic      27752648    win  60.978107
# 120  1972       Richard Nixon    Republican      47168710    win  60.907806
# 79   1920      Warren Harding    Republican      16144093    win  60.574501
# 133  1984       Ronald Reagan    Republican      54455472    win  59.023326
# ..    ...                 ...           ...           ...    ...        ...
# 165  2008    Cynthia McKinney         Green        161797   loss   0.123442
# 148  1996        John Hagelin   Natural Law        113670   loss   0.118219
# 160  2004    Michael Peroutka  Constitution        143630   loss   0.117542
# 141  1992            Bo Gritz      Populist        106152   loss   0.101918
# 156  2004          David Cobb         Green        119859   loss   0.098088
#
#     First Name
# 114     Lyndon
# 91    Franklin
# 120    Richard
# 79      Warren
# 133     Ronald
# ..         ...
# 165    Cynthia
# 148       John
# 160    Michael
# 141         Bo
# 156      David
#
# [182 rows x 7 columns]

# %%
# grab first entry
elections_sorted.groupby("Party").first()
# Out:
#                        Year               Candidate  Popular vote Result  \
# Party
# American               1856        Millard Fillmore        873053   loss
# American Independent   1968          George Wallace       9901118   loss
# Anti-Masonic           1832            William Wirt        100715   loss
# Anti-Monopoly          1884         Benjamin Butler        134294   loss
# Citizens               1980          Barry Commoner        233052   loss
# Communist              1932       William Z. Foster        103307   loss
# Constitution           2008           Chuck Baldwin        199750   loss
# Constitutional Union   1860               John Bell        590901   loss
# Democratic             1964          Lyndon Johnson      43127041    win
# Democratic-Republican  1824          Andrew Jackson        151271   loss
# Dixiecrat              1948          Strom Thurmond       1175930   loss
# Farmer–Labor           1920   Parley P. Christensen        265398   loss
# Free Soil              1848        Martin Van Buren        291501   loss
# Green                  2000             Ralph Nader       2882955   loss
# Greenback              1880         James B. Weaver        308649   loss
# Independent            1992              Ross Perot      19743821   loss
# Liberal Republican     1872          Horace Greeley       2834761   loss
# Libertarian            2016            Gary Johnson       4489235   loss
# National Democratic    1896          John M. Palmer        134645   loss
# National Republican    1828       John Quincy Adams        500897   loss
# National Union         1864         Abraham Lincoln       2211317    win
# Natural Law            1996            John Hagelin        113670   loss
# New Alliance           1988           Lenora Fulani        217221   loss
# Northern Democratic    1860      Stephen A. Douglas       1380202   loss
# Populist               1892         James B. Weaver       1041028   loss
# Progressive            1912      Theodore Roosevelt       4122721   loss
# Prohibition            1892            John Bidwell        270879   loss
# Reform                 1996              Ross Perot       8085294   loss
# Republican             1972           Richard Nixon      47168710    win
# Socialist              1912          Eugene V. Debs        901551   loss
# Southern Democratic    1860    John C. Breckinridge        848019   loss
# States' Rights         1956      T. Coleman Andrews        107929   loss
# Taxpayers              1996         Howard Phillips        184656   loss
# Union                  1936           William Lemke        892378   loss
# Union Labor            1888          Alson Streeter        146602   loss
# Whig                   1840  William Henry Harrison       1275583    win
#
#                                % First Name
# Party
# American               21.554001    Millard
# American Independent   13.571218     George
# Anti-Masonic            7.821583    William
# Anti-Monopoly           1.335838   Benjamin
# Citizens                0.270182      Barry
# Communist               0.261069    William
# Constitution            0.152398      Chuck
# Constitutional Union   12.639283       John
# Democratic             61.344703     Lyndon
# Democratic-Republican  57.210122     Andrew
# Dixiecrat               2.412304      Strom
# Farmer–Labor            0.995804     Parley
# Free Soil              10.138474     Martin
# Green                   2.741176      Ralph
# Greenback               3.352344      James
# Independent            18.956298       Ross
# Liberal Republican     44.071406     Horace
# Libertarian             3.307714       Gary
# National Democratic     0.969566       John
# National Republican    43.796073       John
# National Union         54.951512    Abraham
# Natural Law             0.118219       John
# New Alliance            0.237804     Lenora
# Northern Democratic    29.522311    Stephen
# Populist                8.645038      James
# Progressive            27.457433   Theodore
# Prohibition             2.249468       John
# Reform                  8.408844       Ross
# Republican             60.907806    Richard
# Socialist               6.004354     Eugene
# Southern Democratic    18.138998       John
# States' Rights          0.174883         T.
# Taxpayers               0.192045     Howard
# Union                   1.960733    William
# Union Labor             1.288861      Alson
# Whig                   53.051213    William

# %% [markdown]
# #### Alternative Solutions

# %% [markdown]
# You'll soon discover that with Pandas rich tool set, there's typically more than one way to get to the same answer. Each approach has different tradeoffs in terms of readability, performance, memory consumption, complexity, and more. It will take some experience for you to develop a sense of which approach is better for each problem, but you should, in general, try to think if you can at least envision a different solution to a given problem, especially if you find your current solution to be particularly convoluted or hard to read.
#
# Here are a couple of other ways of obtaining the same result (in each case, we only show the top part with `head()`). The first approach uses `groupby` but finds the location of the maximum value via the `idxmax()` method (look up its documentation!).  We then index and sort by `Party` to match the requested formatting:

# %%
# Use idxmax function
using_idmax = elections_sorted.loc[elections_sorted.groupby("Party")["%"].idxmax()]
using_idmax
# Out:
#      Year               Candidate                  Party  Popular vote Result  \
# 22   1856        Millard Fillmore               American        873053   loss
# 115  1968          George Wallace   American Independent       9901118   loss
# 6    1832            William Wirt           Anti-Masonic        100715   loss
# 38   1884         Benjamin Butler          Anti-Monopoly        134294   loss
# 127  1980          Barry Commoner               Citizens        233052   loss
# 89   1932       William Z. Foster              Communist        103307   loss
# 164  2008           Chuck Baldwin           Constitution        199750   loss
# 24   1860               John Bell   Constitutional Union        590901   loss
# 114  1964          Lyndon Johnson             Democratic      43127041    win
# 0    1824          Andrew Jackson  Democratic-Republican        151271   loss
# 103  1948          Strom Thurmond              Dixiecrat       1175930   loss
# 78   1920   Parley P. Christensen           Farmer–Labor        265398   loss
# 15   1848        Martin Van Buren              Free Soil        291501   loss
# 155  2000             Ralph Nader                  Green       2882955   loss
# 35   1880         James B. Weaver              Greenback        308649   loss
# 143  1992              Ross Perot            Independent      19743821   loss
# 31   1872          Horace Greeley     Liberal Republican       2834761   loss
# 175  2016            Gary Johnson            Libertarian       4489235   loss
# 50   1896          John M. Palmer    National Democratic        134645   loss
# 3    1828       John Quincy Adams    National Republican        500897   loss
# 27   1864         Abraham Lincoln         National Union       2211317    win
# 148  1996            John Hagelin            Natural Law        113670   loss
# 136  1988           Lenora Fulani           New Alliance        217221   loss
# 26   1860      Stephen A. Douglas    Northern Democratic       1380202   loss
# 48   1892         James B. Weaver               Populist       1041028   loss
# 68   1912      Theodore Roosevelt            Progressive       4122721   loss
# 49   1892            John Bidwell            Prohibition        270879   loss
# 150  1996              Ross Perot                 Reform       8085294   loss
# 120  1972           Richard Nixon             Republican      47168710    win
# 66   1912          Eugene V. Debs              Socialist        901551   loss
# 25   1860    John C. Breckinridge    Southern Democratic        848019   loss
# 110  1956      T. Coleman Andrews         States' Rights        107929   loss
# 147  1996         Howard Phillips              Taxpayers        184656   loss
# 93   1936           William Lemke                  Union        892378   loss
# 42   1888          Alson Streeter            Union Labor        146602   loss
# 11   1840  William Henry Harrison                   Whig       1275583    win
#
#              % First Name
# 22   21.554001    Millard
# 115  13.571218     George
# 6     7.821583    William
# 38    1.335838   Benjamin
# 127   0.270182      Barry
# 89    0.261069    William
# 164   0.152398      Chuck
# 24   12.639283       John
# 114  61.344703     Lyndon
# 0    57.210122     Andrew
# 103   2.412304      Strom
# 78    0.995804     Parley
# 15   10.138474     Martin
# 155   2.741176      Ralph
# 35    3.352344      James
# 143  18.956298       Ross
# 31   44.071406     Horace
# 175   3.307714       Gary
# 50    0.969566       John
# 3    43.796073       John
# 27   54.951512    Abraham
# 148   0.118219       John
# 136   0.237804     Lenora
# 26   29.522311    Stephen
# 48    8.645038      James
# 68   27.457433   Theodore
# 49    2.249468       John
# 150   8.408844       Ross
# 120  60.907806    Richard
# 66    6.004354     Eugene
# 25   18.138998       John
# 110   0.174883         T.
# 147   0.192045     Howard
# 93    1.960733    William
# 42    1.288861      Alson
# 11   53.051213    William

# %%
  # This is the computational part, Extract DataFrame based on above mentioned condition

# Apply sort_index to match the formatting above
using_idxmax_sorted = using_idmax.sort_index()
using_idxmax_sorted
# Out:
#      Year               Candidate                  Party  Popular vote Result  \
# 0    1824          Andrew Jackson  Democratic-Republican        151271   loss
# 3    1828       John Quincy Adams    National Republican        500897   loss
# 6    1832            William Wirt           Anti-Masonic        100715   loss
# 11   1840  William Henry Harrison                   Whig       1275583    win
# 15   1848        Martin Van Buren              Free Soil        291501   loss
# 22   1856        Millard Fillmore               American        873053   loss
# 24   1860               John Bell   Constitutional Union        590901   loss
# 25   1860    John C. Breckinridge    Southern Democratic        848019   loss
# 26   1860      Stephen A. Douglas    Northern Democratic       1380202   loss
# 27   1864         Abraham Lincoln         National Union       2211317    win
# 31   1872          Horace Greeley     Liberal Republican       2834761   loss
# 35   1880         James B. Weaver              Greenback        308649   loss
# 38   1884         Benjamin Butler          Anti-Monopoly        134294   loss
# 42   1888          Alson Streeter            Union Labor        146602   loss
# 48   1892         James B. Weaver               Populist       1041028   loss
# 49   1892            John Bidwell            Prohibition        270879   loss
# 50   1896          John M. Palmer    National Democratic        134645   loss
# 66   1912          Eugene V. Debs              Socialist        901551   loss
# 68   1912      Theodore Roosevelt            Progressive       4122721   loss
# 78   1920   Parley P. Christensen           Farmer–Labor        265398   loss
# 89   1932       William Z. Foster              Communist        103307   loss
# 93   1936           William Lemke                  Union        892378   loss
# 103  1948          Strom Thurmond              Dixiecrat       1175930   loss
# 110  1956      T. Coleman Andrews         States' Rights        107929   loss
# 114  1964          Lyndon Johnson             Democratic      43127041    win
# 115  1968          George Wallace   American Independent       9901118   loss
# 120  1972           Richard Nixon             Republican      47168710    win
# 127  1980          Barry Commoner               Citizens        233052   loss
# 136  1988           Lenora Fulani           New Alliance        217221   loss
# 143  1992              Ross Perot            Independent      19743821   loss
# 147  1996         Howard Phillips              Taxpayers        184656   loss
# 148  1996            John Hagelin            Natural Law        113670   loss
# 150  1996              Ross Perot                 Reform       8085294   loss
# 155  2000             Ralph Nader                  Green       2882955   loss
# 164  2008           Chuck Baldwin           Constitution        199750   loss
# 175  2016            Gary Johnson            Libertarian       4489235   loss
#
#              % First Name
# 0    57.210122     Andrew
# 3    43.796073       John
# 6     7.821583    William
# 11   53.051213    William
# 15   10.138474     Martin
# 22   21.554001    Millard
# 24   12.639283       John
# 25   18.138998       John
# 26   29.522311    Stephen
# 27   54.951512    Abraham
# 31   44.071406     Horace
# 35    3.352344      James
# 38    1.335838   Benjamin
# 42    1.288861      Alson
# 48    8.645038      James
# 49    2.249468       John
# 50    0.969566       John
# 66    6.004354     Eugene
# 68   27.457433   Theodore
# 78    0.995804     Parley
# 89    0.261069    William
# 93    1.960733    William
# 103   2.412304      Strom
# 110   0.174883         T.
# 114  61.344703     Lyndon
# 115  13.571218     George
# 120  60.907806    Richard
# 127   0.270182      Barry
# 136   0.237804     Lenora
# 143  18.956298       Ross
# 147   0.192045     Howard
# 148   0.118219       John
# 150   8.408844       Ross
# 155   2.741176      Ralph
# 164   0.152398      Chuck
# 175   3.307714       Gary

# %% [markdown]
# Another approach is listed below. And this one doesn't even use `groupby`!
#
# This approach instead uses the `drop_duplicates` method to keep only the last occurrence of of each party after having sorted by "%", which is the best performance.

# %%
# Formatting, Again, the 2nd line is purely formatting:
best_per_party2 = elections.sort_values("%").drop_duplicates(["Party"], keep="last")
best_per_party2
# Out:
#      Year               Candidate                  Party  Popular vote Result  \
# 148  1996            John Hagelin            Natural Law        113670   loss
# 164  2008           Chuck Baldwin           Constitution        199750   loss
# 110  1956      T. Coleman Andrews         States' Rights        107929   loss
# 147  1996         Howard Phillips              Taxpayers        184656   loss
# 136  1988           Lenora Fulani           New Alliance        217221   loss
# 89   1932       William Z. Foster              Communist        103307   loss
# 127  1980          Barry Commoner               Citizens        233052   loss
# 50   1896          John M. Palmer    National Democratic        134645   loss
# 78   1920   Parley P. Christensen           Farmer–Labor        265398   loss
# 42   1888          Alson Streeter            Union Labor        146602   loss
# 38   1884         Benjamin Butler          Anti-Monopoly        134294   loss
# 93   1936           William Lemke                  Union        892378   loss
# 49   1892            John Bidwell            Prohibition        270879   loss
# 103  1948          Strom Thurmond              Dixiecrat       1175930   loss
# 155  2000             Ralph Nader                  Green       2882955   loss
# 175  2016            Gary Johnson            Libertarian       4489235   loss
# 35   1880         James B. Weaver              Greenback        308649   loss
# 66   1912          Eugene V. Debs              Socialist        901551   loss
# 6    1832            William Wirt           Anti-Masonic        100715   loss
# 150  1996              Ross Perot                 Reform       8085294   loss
# 48   1892         James B. Weaver               Populist       1041028   loss
# 15   1848        Martin Van Buren              Free Soil        291501   loss
# 24   1860               John Bell   Constitutional Union        590901   loss
# 115  1968          George Wallace   American Independent       9901118   loss
# 25   1860    John C. Breckinridge    Southern Democratic        848019   loss
# 143  1992              Ross Perot            Independent      19743821   loss
# 22   1856        Millard Fillmore               American        873053   loss
# 68   1912      Theodore Roosevelt            Progressive       4122721   loss
# 26   1860      Stephen A. Douglas    Northern Democratic       1380202   loss
# 3    1828       John Quincy Adams    National Republican        500897   loss
# 31   1872          Horace Greeley     Liberal Republican       2834761   loss
# 11   1840  William Henry Harrison                   Whig       1275583    win
# 27   1864         Abraham Lincoln         National Union       2211317    win
# 0    1824          Andrew Jackson  Democratic-Republican        151271   loss
# 120  1972           Richard Nixon             Republican      47168710    win
# 114  1964          Lyndon Johnson             Democratic      43127041    win
#
#              % First Name
# 148   0.118219       John
# 164   0.152398      Chuck
# 110   0.174883         T.
# 147   0.192045     Howard
# 136   0.237804     Lenora
# 89    0.261069    William
# 127   0.270182      Barry
# 50    0.969566       John
# 78    0.995804     Parley
# 42    1.288861      Alson
# 38    1.335838   Benjamin
# 93    1.960733    William
# 49    2.249468       John
# 103   2.412304      Strom
# 155   2.741176      Ralph
# 175   3.307714       Gary
# 35    3.352344      James
# 66    6.004354     Eugene
# 6     7.821583    William
# 150   8.408844       Ross
# 48    8.645038      James
# 15   10.138474     Martin
# 24   12.639283       John
# 115  13.571218     George
# 25   18.138998       John
# 143  18.956298       Ross
# 22   21.554001    Millard
# 68   27.457433   Theodore
# 26   29.522311    Stephen
# 3    43.796073       John
# 31   44.071406     Horace
# 11   53.051213    William
# 27   54.951512    Abraham
# 0    57.210122     Andrew
# 120  60.907806    Richard
# 114  61.344703     Lyndon

# %% [markdown]
# *Challenge:* See if you can find yet another approach that still gives the same answer.

# %% [markdown]
# ### `DataFrameGroupBy` Objects

# %% [markdown]
# The result of `groupby` is not a `DataFrame` or a list of `DataFrame`s. It is instead a special type called a `DataFrameGroupBy`.

# %%
grouped_by_party = elections.groupby("Party")
type(grouped_by_party)
elections
# Out:
#      Year          Candidate                  Party  Popular vote Result  \
# 0    1824     Andrew Jackson  Democratic-Republican        151271   loss
# 1    1824  John Quincy Adams  Democratic-Republican        113142    win
# 2    1828     Andrew Jackson             Democratic        642806    win
# 3    1828  John Quincy Adams    National Republican        500897   loss
# 4    1832     Andrew Jackson             Democratic        702735    win
# ..    ...                ...                    ...           ...    ...
# 177  2016         Jill Stein                  Green       1457226   loss
# 178  2020       Joseph Biden             Democratic      81268924    win
# 179  2020       Donald Trump             Republican      74216154   loss
# 180  2020       Jo Jorgensen            Libertarian       1865724   loss
# 181  2020     Howard Hawkins                  Green        405035   loss
#
#              %
# 0    57.210122
# 1    42.789878
# 2    56.203927
# 3    43.796073
# 4    54.574789
# ..         ...
# 177   1.073699
# 178  51.311515
# 179  46.858542
# 180   1.177979
# 181   0.255731
#
# [182 rows x 6 columns]

# %% [markdown]
# `GroupBy` objects are structured like dictionaries. In fact, we can actually see the dictionaries with the following code:

# %%
# visualize all groups using .groups
grouped_by_party.groups
# Out:
# {'American': [22, 126], 'American Independent': [115, 119, 124], 'Anti-Masonic': [6], 'Anti-Monopoly': [38], 'Citizens': [127], 'Communist': [89], 'Constitution': [160, 164, 172], 'Constitutional Union': [24], 'Democratic': [2, 4, 8, 10, 13, 14, 17, 20, 28, 29, 34, 37, 39, 45, 47, 52, 55, 57, 64, 70, 74, 77, 81, 83, 86, 91, 94, 97, 100, 105, 108, 111, 114, 116, 118, 123, 129, 134, 137, 140, 144, 151, 158, 162, 168, 176, 178], 'Democratic-Republican': [0, 1], 'Dixiecrat': [103], 'Farmer–Labor': [78], 'Free Soil': [15, 18], 'Green': [149, 155, 156, 165, 170, 177, 181], 'Greenback': [35], 'Independent': [121, 130, 143, 161, 167, 174], 'Liberal Republican': [31], 'Libertarian': [125, 128, 132, 138, 139, 146, 153, 159, 163, 169, 175, 180], 'National Democratic': [50], 'National Republican': [3, 5], 'National Union': [27], 'Natural Law': [148], 'New Alliance': [136], 'Northern Democratic': [26], 'Populist': [48, 61, 141], 'Progressive': [68, 82, 101, 107], 'Prohibition': [41, 44, 49, 51, 54, 59, 63, 67, 73, 75, 99], 'Reform': [150, 154], 'Republican': [21, 23, 30, 32, 33, 36, 40, 43, 46, 53, 56, 60, 65, 69, 72, 79, 80, 84, 87, 90, 96, 98, 104, 106, 109, 112, 113, 117, 120, 122, 131, 133, 135, 142, 145, 152, 157, 166, 171, 173, 179], 'Socialist': [58, 62, 66, 71, 76, 85, 88, 92, 95, 102], 'Southern Democratic': [25], 'States' Rights': [110], 'Taxpayers': [147], 'Union': [93], 'Union Labor': [42], 'Whig': [7, 9, 11, 12, 16, 19]}

# %% [markdown]
# The `key`s of the dictionary are the groups (in this case, `Party`), and the `value`s are the **indices** of rows belonging to that group. We can access a particular sub-`DataFrame` using `get_group`:

# %%
# use get_group to extract 'Socialists' party results
grouped_by_party.get_group('Socialist')
# Out:
#      Year        Candidate      Party  Popular vote Result         %
# 58   1904   Eugene V. Debs  Socialist        402810   loss  2.985897
# 62   1908   Eugene V. Debs  Socialist        420852   loss  2.850866
# 66   1912   Eugene V. Debs  Socialist        901551   loss  6.004354
# 71   1916  Allan L. Benson  Socialist        590524   loss  3.194193
# 76   1920   Eugene V. Debs  Socialist        913693   loss  3.428282
# 85   1928    Norman Thomas  Socialist        267478   loss  0.728623
# 88   1932    Norman Thomas  Socialist        884885   loss  2.236211
# 92   1936    Norman Thomas  Socialist        187910   loss  0.412876
# 95   1940    Norman Thomas  Socialist        116599   loss  0.234237
# 102  1948    Norman Thomas  Socialist        139569   loss  0.286312

# %% [markdown]
# ## Pivot Tables

# %% [markdown]
# ### `Groupby` with multiple columns

# %% [markdown]
# We want to build a table showing the total number of babies born of each sex in each year. One way is to `groupby` using both columns of interest:

# %%
# Find total count of baby names for both female and Male for each year
import urllib.request
import os.path
import zipfile

data_url = "https://www.ssa.gov/oact/babynames/state/namesbystate.zip"
local_filename = "D:\Workbook assignments\babynamesbystate.zip"
if not os.path.exists(local_filename): # If the data exists don't download again
    with urllib.request.urlopen(data_url) as resp, open(local_filename, 'wb') as f:
        f.write(resp.read())

zf = zipfile.ZipFile(local_filename, 'r')

ca_name = 'CA.TXT'
field_names = ['State', 'Sex', 'Year', 'Name', 'Count']
with zf.open(ca_name) as fh:
    babynames = pd.read_csv(fh, header=None, names=field_names)

babynames.head()
babynames.groupby(['Year','Sex'])[['Count']].agg(sum).head(6)
# Out:
# <ipython-input-25-40d674b27b5c>:20: FutureWarning: The provided callable <built-in function sum> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   babynames.groupby(['Year','Sex'])[['Count']].agg(sum).head(6)
#           Count
# Year Sex
# 1910 F     5950
#      M     3213
# 1911 F     6602
#      M     3381
# 1912 F     9804
#      M     8142

# %% [markdown]
# ### `pivot_table`

# %%
# Find total count of baby names for both female and Male for each year using Pivot table
babynames_pivot = babynames.pivot_table(
    index= 'Year',
    columns= 'Sex',
    values= ['Count'],
    aggfunc= np.sum
)
babynames_pivot.head(6)
# Out:
# <ipython-input-19-a383648bed05>:2: FutureWarning: The provided callable <function sum at 0x794feff83250> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   babynames_pivot = babynames.pivot_table(
#       Count
# Sex       F      M
# Year
# 1910   5950   3213
# 1911   6602   3381
# 1912   9804   8142
# 1913  11860  10234
# 1914  13815  13111
# 1915  18643  17192

# %% [markdown]
# ### `pivot_table` with Multiple values

# %%
# Form a pivot table as describe in Lecture Slides
babynames_pivot = babynames.pivot_table(
    index= 'Year',
    columns= 'Sex',
    values= ['Count','Name'],
    aggfunc= np.max
)
babynames_pivot.head(6)
# Out:
# <ipython-input-20-8ff37a00f43c>:2: FutureWarning: The provided callable <function max at 0x794feff83880> is currently using DataFrameGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   babynames_pivot = babynames.pivot_table(
#      Count          Name
# Sex      F     M       F        M
# Year
# 1910   295   237  Yvonne  William
# 1911   390   214   Zelma   Willis
# 1912   534   501  Yvonne  Woodrow
# 1913   584   614   Zelma   Yoshio
# 1914   773   769   Zelma   Yoshio
# 1915   998  1033    Zita    Yukio

# %% [markdown]
# ## Join Tables
#
# What if we want to know the popularity of presidential candidates' first names in California in 2022? What can we do?

# %%
elections.head(10)
# Out:
#    Year               Candidate                  Party  Popular vote Result  \
# 0  1824          Andrew Jackson  Democratic-Republican        151271   loss
# 1  1824       John Quincy Adams  Democratic-Republican        113142    win
# 2  1828          Andrew Jackson             Democratic        642806    win
# 3  1828       John Quincy Adams    National Republican        500897   loss
# 4  1832          Andrew Jackson             Democratic        702735    win
# 5  1832              Henry Clay    National Republican        484205   loss
# 6  1832            William Wirt           Anti-Masonic        100715   loss
# 7  1836       Hugh Lawson White                   Whig        146109   loss
# 8  1836        Martin Van Buren             Democratic        763291    win
# 9  1836  William Henry Harrison                   Whig        550816   loss
#
#            %
# 0  57.210122
# 1  42.789878
# 2  56.203927
# 3  43.796073
# 4  54.574789
# 5  37.603628
# 6   7.821583
# 7  10.005985
# 8  52.272472
# 9  37.721543

# %%
# Collect baby names for 2022
babynames_2022 = babynames[babynames['Year'] == 2022]
babynames_2022
# Out:
#        State Sex  Year    Name  Count
# 235861    CA   F  2022  Olivia   2184
# 235862    CA   F  2022    Emma   2086
# 235863    CA   F  2022  Camila   2048
# 235864    CA   F  2022     Mia   1890
# 235865    CA   F  2022  Sophia   1770
# ...      ...  ..   ...     ...    ...
# 411107    CA   M  2022     Zia      5
# 411108    CA   M  2022    Zora      5
# 411109    CA   M  2022    Zuri      5
# 411110    CA   M  2022  Zuriel      5
# 411111    CA   M  2022    Zylo      5
#
# [6607 rows x 5 columns]

# %%
# Use split the candidate names in elections dataframe
elections['First Name'] = elections['Candidate'].str.split().str[0]
elections
# Out:
#      Year          Candidate                  Party  Popular vote Result  \
# 0    1824     Andrew Jackson  Democratic-Republican        151271   loss
# 1    1824  John Quincy Adams  Democratic-Republican        113142    win
# 2    1828     Andrew Jackson             Democratic        642806    win
# 3    1828  John Quincy Adams    National Republican        500897   loss
# 4    1832     Andrew Jackson             Democratic        702735    win
# ..    ...                ...                    ...           ...    ...
# 177  2016         Jill Stein                  Green       1457226   loss
# 178  2020       Joseph Biden             Democratic      81268924    win
# 179  2020       Donald Trump             Republican      74216154   loss
# 180  2020       Jo Jorgensen            Libertarian       1865724   loss
# 181  2020     Howard Hawkins                  Green        405035   loss
#
#              % First Name
# 0    57.210122     Andrew
# 1    42.789878       John
# 2    56.203927     Andrew
# 3    43.796073       John
# 4    54.574789     Andrew
# ..         ...        ...
# 177   1.073699       Jill
# 178  51.311515     Joseph
# 179  46.858542     Donald
# 180   1.177979         Jo
# 181   0.255731     Howard
#
# [182 rows x 7 columns]

# %% [markdown]
# `join` in pandas

# %%
#Merge both elections and babynames and report your analysis
merged = pd.merge(left=elections,right=babynames_2022,left_on="First Name",right_on="Name")
merged

#Analysis
#1. Many historical politicians name are still common in year 2022
#2. Both the losing and winning candidate names are common still now
#3. Many names lose there popularity which shows change in trends
# Out:
#      Year_x          Candidate                  Party  Popular vote Result  \
# 0      1824     Andrew Jackson  Democratic-Republican        151271   loss
# 1      1824  John Quincy Adams  Democratic-Republican        113142    win
# 2      1828     Andrew Jackson             Democratic        642806    win
# 3      1828  John Quincy Adams    National Republican        500897   loss
# 4      1832     Andrew Jackson             Democratic        702735    win
# ..      ...                ...                    ...           ...    ...
# 149    2016       Gary Johnson            Libertarian       4489235   loss
# 150    2016    Hillary Clinton             Democratic      65853514   loss
# 151    2020       Joseph Biden             Democratic      81268924    win
# 152    2020       Donald Trump             Republican      74216154   loss
# 153    2020     Howard Hawkins                  Green        405035   loss
#
#              % First Name State Sex  Year_y     Name  Count
# 0    57.210122     Andrew    CA   M    2022   Andrew    743
# 1    42.789878       John    CA   M    2022     John    494
# 2    56.203927     Andrew    CA   M    2022   Andrew    743
# 3    43.796073       John    CA   M    2022     John    494
# 4    54.574789     Andrew    CA   M    2022   Andrew    743
# ..         ...        ...   ...  ..     ...      ...    ...
# 149   3.307714       Gary    CA   M    2022     Gary     20
# 150  48.521539    Hillary    CA   F    2022  Hillary     10
# 151  51.311515     Joseph    CA   M    2022   Joseph    792
# 152  46.858542     Donald    CA   M    2022   Donald     33
# 153   0.255731     Howard    CA   M    2022   Howard     18
#
# [154 rows x 12 columns]

# %%
# Sort using Count
merged.sort_values(by="Count")
# Out:
#      Year_x          Candidate          Party  Popular vote Result          %  \
# 145    2016     Darrell Castle   Constitution        203091   loss   0.149640
# 78     1928     Herbert Hoover     Republican      21427123    win  58.368524
# 81     1932     Herbert Hoover     Republican      15761254   loss  39.830594
# 69     1916     Woodrow Wilson     Democratic       9126868    win  49.367987
# 99     1964     Lyndon Johnson     Democratic      43127041    win  61.344703
# ..      ...                ...            ...           ...    ...        ...
# 38     1884    James G. Blaine     Republican       4856905   loss  48.312208
# 14     1844         James Polk     Democratic       1339570    win  50.749477
# 36     1884    Benjamin Butler  Anti-Monopoly        134294   loss   1.335838
# 42     1892  Benjamin Harrison     Republican       5176108   loss  42.984101
# 40     1888  Benjamin Harrison     Republican       5443633    win  47.858041
#
#     First Name State Sex  Year_y      Name  Count
# 145    Darrell    CA   M    2022   Darrell      5
# 78     Herbert    CA   M    2022   Herbert      5
# 81     Herbert    CA   M    2022   Herbert      5
# 69     Woodrow    CA   M    2022   Woodrow      6
# 99      Lyndon    CA   M    2022    Lyndon      6
# ..         ...   ...  ..     ...       ...    ...
# 38       James    CA   M    2022     James   1094
# 14       James    CA   M    2022     James   1094
# 36    Benjamin    CA   M    2022  Benjamin   1528
# 42    Benjamin    CA   M    2022  Benjamin   1528
# 40    Benjamin    CA   M    2022  Benjamin   1528
#
# [154 rows x 12 columns]
